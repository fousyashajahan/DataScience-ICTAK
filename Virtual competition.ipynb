# %% [markdown]
# Consider the following Python dictionary `data` and Python list `labels`:
#
# ``` python
# data = {'animal': ['cat', 'cat', 'snake', 'dog', 'dog', 'cat', 'snake', 'cat', 'dog', 'dog'],
#         'age': [2.5, 3, 0.5, np.nan, 5, 2, 4.5, np.nan, 7, 3],
#         'visits': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
#         'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}
#
# labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
# ```
#
# **1.** Create a DataFrame `df` from this dictionary `data` which has the index `labels`.

# %%
import pandas as pd
import numpy as np

# %%
data = {'animal': ['cat', 'cat', 'snake', 'dog', 'dog', 'cat', 'snake', 'cat', 'dog', 'dog'],
        'age': [2.5, 3, 0.5, np.nan, 5, 2, 4.5, np.nan, 7, 3],
        'visits': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
        'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}

labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

df=pd.DataFrame(data,index=labels)
df
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  2.0       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no

# %% [markdown]
# **2.** Display a summary of the basic information about this DataFrame and its data (*hint: there is a single method that can be called on the DataFrame*).

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, a to j
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   animal    10 non-null     object
#  1   age       8 non-null      float64
#  2   visits    10 non-null     int64
#  3   priority  10 non-null     object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 700.0+ bytes

# %% [markdown]
# **3.** Return the first 3 rows of the DataFrame `df`.

# %%
df.head(3)
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no

# %% [markdown]
# **4.** Display the 'animal' and 'age' columns from the DataFrame `df`

# %%
df[['animal', 'age']]
# Out:
#   animal  age
# a    cat  2.5
# b    cat  3.0
# c  snake  0.5
# d    dog  NaN
# e    dog  5.0
# f    cat  2.0
# g  snake  4.5
# h    cat  NaN
# i    dog  7.0
# j    dog  3.0

# %% [markdown]
# **5.** Display the data in rows `[3, 4, 8]` *and* in columns `['animal', 'age']'

# %%
df.loc[['d', 'e', 'i'], ['animal', 'age']]
# Out:
#   animal  age
# d    dog  NaN
# e    dog  5.0
# i    dog  7.0

# %% [markdown]
# **6.** Select only the rows where the number of visits is greater than 3.

# %%
df[df['visits'] > 3]
# Out:
# Empty DataFrame
# Columns: [animal, age, visits, priority]
# Index: []

# %% [markdown]
# **7.** Select the rows where the age is missing, i.e. it is `NaN`.

# %%
df[df['age'].isnull()]
# Out:
#   animal  age  visits priority
# d    dog  NaN       3      yes
# h    cat  NaN       1      yes

# %% [markdown]
# **8.** Select the rows where the animal is a cat *and* the age is less than 3.

# %%
df[(df['animal'] == 'cat') & (df['age'] < 3)]
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# f    cat  2.0       3       no

# %% [markdown]
# **9.** Select the rows where the age is between 2 and 4 (inclusive)

# %%
df[(df['age'] >= 2) & (df['age'] <= 4)]
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# f    cat  2.0       3       no
# j    dog  3.0       1       no

# %% [markdown]
# **10.** Change the age in row 'f' to 1.5.

# %%
df.loc['f', 'age'] = 1.5
df
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  1.5       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no

# %% [markdown]
# **11.** Calculate the sum of all visits in `df` (i.e. the total number of visits).

# %%
df['visits'].sum()
# Out:
# 19

# %% [markdown]
# **12.** Calculate the mean age for each different animal in `df`.

# %%
df.groupby('animal')['age'].mean()
# Out:
# animal
# cat      2.333333
# dog      5.000000
# snake    2.500000
# Name: age, dtype: float64

# %% [markdown]
# **13.** Append a new row 'k' to `df` with your choice of values for each column. Then delete that row to return the original DataFrame.

# %%
df.loc['k'] = {'animal': 'goat', 'age': 4, 'visits': 2, 'priority': 'yes'}
df
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  1.5       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no
# k   goat  4.0       2      yes

# %%
df = df.drop('k')
print(df)
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  1.5       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no

# %% [markdown]
# **14.** Count the number of each type of animal in `df`.

# %%
df['animal'].value_counts()
# Out:
# animal
# cat      4
# dog      4
# snake    2
# Name: count, dtype: int64

# %% [markdown]
# **15.** Sort `df` first by the values in the 'age' in *decending* order, then by the value in the 'visits' column in *ascending* order (so row `i` should be first, and row `d` should be last).

# %%
df.sort_values(by=['age', 'visits'], ascending=[False, True])
# Out:
#   animal  age  visits priority
# i    dog  7.0       2       no
# e    dog  5.0       2       no
# g  snake  4.5       1       no
# j    dog  3.0       1       no
# b    cat  3.0       3      yes
# a    cat  2.5       1      yes
# f    cat  1.5       3       no
# c  snake  0.5       2       no
# h    cat  NaN       1      yes
# d    dog  NaN       3      yes

# %% [markdown]
# **16.** The 'priority' column contains the values 'yes' and 'no'. Replace this column with a column of boolean values: 'yes' should be `True` and 'no' should be `False`.

# %%
df['priority'].replace({'yes': True, 'no': False})
df
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  1.5       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no

# %% [markdown]
# **17.** In the 'animal' column, change the 'snake' entries to 'python'.

# %%
df['animal'].replace('snake', 'python')
# Out:
# a       cat
# b       cat
# c    python
# d       dog
# e       dog
# f       cat
# g    python
# h       cat
# i       dog
# j       dog
# Name: animal, dtype: object

# %% [markdown]
# # **ny-flights**

# %% [markdown]
# **18.** Load the ny-flights dataset to Python

# %%
data=pd.read_csv('/content/ny-flights.csv')
data
# Out:
#                    fl_date unique_carrier  airline_id tail_num  fl_num origin  \
# 0      2014-01-01 00:00:00             AA       19805   N338AA       1    JFK
# 1      2014-01-01 00:00:00             AA       19805   N335AA       3    JFK
# 2      2014-01-01 00:00:00             AA       19805   N327AA      21    JFK
# 3      2014-01-01 00:00:00             AA       19805   N3EHAA      29    LGA
# 4      2014-01-01 00:00:00             AA       19805   N319AA     117    JFK
# ...                    ...            ...         ...      ...     ...    ...
# 20812  2014-01-31 00:00:00             UA       19977   N54711    1253    ROC
# 20813  2014-01-31 00:00:00             UA       19977   N77525    1429    LGA
# 20814  2014-01-31 00:00:00             UA       19977   N37293    1456    LGA
# 20815  2014-01-31 00:00:00             UA       19977   N24729    1457    LGA
# 20816  2014-01-31 00:00:00             MQ       20398   N609MQ    3699    BUF
#
# ...

# %% [markdown]
# **19.** Which airline ID is present maximum times in the dataset

# %%
count=data['airline_id'].value_counts()
maxID=count.idxmax()

print("The airline ID present maximum times is '{maxID}")
# Out:
# The airline ID present maximum times is '{maxID}

# %% [markdown]
# **20.** Draw a plot between dep_delay and arr_delay

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,6))
plt.bar(data['dep_delay'],data['arr_delay'],color="forestgreen")
plt.title('Bar Plot of Departure Delay vs Arrival Delay')
plt.xlabel('Departure Delay')
plt.ylabel('Arrival Delay')
plt.show()

# %% [markdown]
# ### *The bar plot highlights the relationship between departure and arrival delays, revealing that flights are more likely to arrive late if they depart late. This shows a positive correlation between departure delay and arrival delay.*

# %% [markdown]
# # **Diabetes_model**

# %%
diabetic_data=pd.read_csv('/content/diabetes_model.csv')
diabetic_data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              5       77             82             41       42  35.8
# 1              9      122             56              0        0  33.3
# 2              0      113             76              0        0  33.3
# 3              1      139             62             41      480  40.7
# 4             10      161             68             23      132  25.5
# ..           ...      ...            ...            ...      ...   ...
# 609            4      114             64              0        0  28.9
# 610            2      175             88              0        0  22.9
# 611            3      121             52              0        0  36.0
# 612            7      136             74             26      135  26.0
# 613            4      156             75              0        0  48.3
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.156   35        0
# ...

# %% [markdown]
# # **Univariate Analysis**
# ### **Analyze individual variables (e.g., histograms, box plots).**

# %% [markdown]
# # ***Histogram***

# %%
import seaborn as sns
sns.histplot(diabetic_data['BloodPressure'],bins=10,color='#614d37',edgecolor='black')
plt.show()

# %% [markdown]
# ### *This histogram depicts the distribution of blood pressure readings in the 'diabetic_data'.*
# ### *The x-axis represents the blood pressure range segmented into 10 bins*
# ### *The y-axis represents the frequency or count of blood pressure readings within each bin.*

# %% [markdown]
# # ***Box plot***

# %%
plt.figure(figsize=(5, 5))
sns.boxplot(diabetic_data['Pregnancies'],color="green")
plt.title('Box Plot')
plt.show()

# %% [markdown]
# ### *The median number of pregnancies is between 2.5 and 5.0*
# ### *There are a few outliers visible above the upper whisker representing individuals with a substantially higher number of pregnancies compared to the rest of the population.*

# %% [markdown]
# #**Bivariate Analysis**
# ### **Explore relationships between pairs of variables (e.g., scatter plots, correlation matrices).**

# %% [markdown]
# # ***correlation matrix***

# %%
corr_mat= diabetic_data[['Pregnancies','Glucose']]
corr = corr_mat.corr()
plt.figure(figsize=(6, 5))
sns.heatmap(corr, annot=True, cmap='Greens')
plt.title('Heatmap of Correlation Matrix')
plt.show()

# %% [markdown]
# ### *1 indicates a perfect positive correlation.*
# ### *-1 indicates a perfect negative correlation.*
# ### *0 indicates no linear correlation*

# %% [markdown]
# # ***scatter plot***

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Glucose', y='DiabetesPedigreeFunction', hue='Outcome', data=diabetic_data, palette='dark')
plt.title(' Glucose vs DiabetesPedigreeFunction')
plt.show()

# %% [markdown]
# ### *The scatter plot emphasizes the individual variability in the relationship between glucose levels and diabetes pedigree function. Even within the same outcome group, there can be a wide range of values for both variables.*

# %% [markdown]
# # **Multivariate Analysis**
# ### **Investigate interactions among multiple variables (e.g., pair plots, 3D plots)**

# %% [markdown]
# # ***Pair plot***

# %%
plt.figure(figsize=(10, 6))
sns.pairplot(diabetic_data[['Glucose','BloodPressure','BMI']],hue='BMI',palette='viridis')
plt.show()

# %% [markdown]
# ### *The pairplot visualizes the relationships between three variables: Glucose, Blood Pressure, and BMI, using the 'diabetic_data' dataset.*
#
# ### *There seems to be a weak positive correlation between glucose and blood pressure. As glucose levels increase, blood pressure tends to increase slightly*
#
# ### *Individuals with higher BMI values tend to have slightly higher blood pressure, but this relationship is not very strong.*

# %% [markdown]
# # ***3D plot***

# %%
x = diabetic_data['Pregnancies']
y = diabetic_data['Glucose']
z = diabetic_data['Age']

fig = plt.figure(figsize=(15, 8))
ax = fig.add_subplot(111, projection='3d')

ax.scatter(x, y, z, alpha=0.5,color='brown')
ax.set_xlabel('Pregnancies')
ax.set_ylabel('Glucose')
ax.set_zlabel('Age')
ax.set_title('3D Scatter Plot of Pregnancies, Glucose, and Age')

plt.show()

# %% [markdown]
# ### *The 3D scatter plot provides a visual overview of the relationships between pregnancies, glucose, and Age.*
#
# ### *The general clustering of data points are in the lower regions of the plot, suggesting that a majority of individuals have lower values for pregnancies, glucose, and Age*
