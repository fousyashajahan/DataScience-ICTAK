# %%
import pandas as pd
import numpy as np

# %%
pd.read_csv('Food Nutrition Dataset.csv')
# Out:
#      Unnamed: 0.1  Unnamed: 0                      food  Caloric Value  \
# 0               0           0    margarine with yoghurt             88
# 1               1           1     sunflower seed butter             99
# 2               2           2              hazelnut oil            120
# 3               3           3         menhaden fish oil           1966
# 4               4           4        cod liver fish oil            123
# ..            ...         ...                       ...            ...
# 717           717         717                  jews ear             25
# 718           718         718           enoki mushrooms              1
# 719           719         719           morel mushrooms              4
# 720           720         720  portabella mushrooms raw             19
# 721           721         721           oyster mushroom              5
#
#          Fat  Saturated Fats  Monounsaturated Fats  Polyunsaturated Fats  \
# ...

# %%
data = pd.read_csv('Food Nutrition Dataset.csv')
data.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0                    food  Caloric Value    Fat  \
# 0             0           0  margarine with yoghurt             88    9.8
# 1             1           1   sunflower seed butter             99    8.8
# 2             2           2            hazelnut oil            120   13.6
# 3             3           3       menhaden fish oil           1966  218.0
# 4             4           4      cod liver fish oil            123   13.6
#
#    Saturated Fats  Monounsaturated Fats  Polyunsaturated Fats  Carbohydrates  \
# 0             1.9                   5.6                   2.0          0.073
# 1             0.7                   6.2                   1.6          3.700
# 2             1.0                  10.6                   1.4          0.000
# 3            66.3                  58.2                  74.5          0.000
# 4             3.1                   6.4                   3.1          0.000
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 722 entries, 0 to 721
# Data columns (total 37 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0.1          722 non-null    int64
#  1   Unnamed: 0            722 non-null    int64
#  2   food                  722 non-null    object
#  3   Caloric Value         722 non-null    int64
#  4   Fat                   722 non-null    float64
#  5   Saturated Fats        722 non-null    float64
#  6   Monounsaturated Fats  722 non-null    float64
#  7   Polyunsaturated Fats  722 non-null    float64
#  8   Carbohydrates         722 non-null    float64
#  9   Sugars                722 non-null    float64
#  10  Protein               722 non-null    float64
#  11  Dietary Fiber         722 non-null    float64
#  12  Cholesterol           722 non-null    float64
#  13  Sodium                722 non-null    float64
# ...

# %% [markdown]
#  **Q1: What is the size of the dataset? (Number of rows and columns)**

# %%
data.shape
# Out:
# (722, 37)

# %% [markdown]
# **Q2: What are the data types of each column?**

# %%
data.dtypes
# Out:
# Unnamed: 0.1              int64
# Unnamed: 0                int64
# food                     object
# Caloric Value             int64
# Fat                     float64
# Saturated Fats          float64
# Monounsaturated Fats    float64
# Polyunsaturated Fats    float64
# Carbohydrates           float64
# Sugars                  float64
# Protein                 float64
# Dietary Fiber           float64
# Cholesterol             float64
# Sodium                  float64
# Water                   float64
# Vitamin A               float64
# Vitamin B1              float64
# Vitamin B11             float64
# Vitamin B12             float64
# Vitamin B2              float64
# Vitamin B3              float64
# Vitamin B5              float64
# Vitamin B6              float64
# Vitamin C               float64
# Vitamin D               float64
# Vitamin E               float64
# Vitamin K               float64
# Calcium                 float64
# Copper                  float64
# ...

# %% [markdown]
# **Q3: Are there any missing values in the dataset? If so, which columns have
# missing values and how many?**

# %%
data.isnull()    # To identify missing values
# Out:
#      Unnamed: 0.1  Unnamed: 0   food  Caloric Value    Fat  Saturated Fats  \
# 0           False       False  False          False  False           False
# 1           False       False  False          False  False           False
# 2           False       False  False          False  False           False
# 3           False       False  False          False  False           False
# 4           False       False  False          False  False           False
# ..            ...         ...    ...            ...    ...             ...
# 717         False       False  False          False  False           False
# 718         False       False  False          False  False           False
# 719         False       False  False          False  False           False
# 720         False       False  False          False  False           False
# 721         False       False  False          False  False           False
#
# ...

# %%
data.isnull().sum()   #  To count the number of missing values in each column
# Out:
# Unnamed: 0.1            0
# Unnamed: 0              0
# food                    0
# Caloric Value           0
# Fat                     0
# Saturated Fats          0
# Monounsaturated Fats    0
# Polyunsaturated Fats    0
# Carbohydrates           0
# Sugars                  0
# Protein                 0
# Dietary Fiber           0
# Cholesterol             0
# Sodium                  0
# Water                   0
# Vitamin A               0
# Vitamin B1              0
# Vitamin B11             0
# Vitamin B12             0
# Vitamin B2              0
# Vitamin B3              0
# Vitamin B5              0
# Vitamin B6              0
# Vitamin C               0
# Vitamin D               0
# Vitamin E               0
# Vitamin K               0
# Calcium                 0
# Copper                  0
# Iron                    0
# Magnesium               0
# Manganese               0
# Phosphorus              0
# Potassium               0
# Selenium                0
# ...

# %%
# Filter out columns with missing values

miss_values = miss_values[miss_values > 0]
print(miss_values)
# Out:
# Series([], dtype: int64)

# %% [markdown]
# **Q4. What are the unique values in a categorical column of your choice? How
# many unique values are there?**

# %%
data['Sugars'].unique()
# Out:
# array([0.00e+00, 1.70e+00, 7.00e-01, 1.40e-02, 8.00e-01, 5.00e-01,
#        1.50e+00, 3.00e-01, 1.00e+00, 2.80e+00, 4.10e-02, 5.20e-02,
#        1.10e+00, 1.30e+00, 2.00e-01, 1.80e+00, 1.79e+01, 6.70e+00,
#        7.00e+00, 1.17e+01, 5.40e+00, 3.00e+00, 2.63e+01, 1.40e+00,
#        1.44e+01, 1.92e+01, 2.00e+00, 1.24e+01, 1.48e+01, 1.08e+01,
#        9.00e-01, 4.80e+00, 3.50e+00, 1.60e+00, 2.30e+00, 6.00e-01,
#        4.00e-01, 1.20e+00, 2.20e+00, 7.90e+00, 1.00e-01, 3.10e+00,
#        5.30e+00, 2.40e+00, 6.00e+00, 6.20e+00, 3.32e+01, 3.00e+01,
#        9.60e+00, 5.10e-02, 2.20e+01, 5.00e+00, 5.70e+00, 5.80e+00,
#        7.10e+00, 2.61e+01, 5.90e+00, 4.30e+00, 6.30e-02, 2.10e+00,
#        8.40e-02, 9.80e-02, 2.80e-02, 1.05e+01, 3.60e+00, 6.00e-03,
#        3.20e+00, 8.80e-02, 1.90e-02, 2.70e+00, 6.20e-02, 3.10e-02,
#        8.40e+00, 4.00e-02, 7.00e-03, 2.50e+00, 1.40e+01, 3.70e+00,
#        6.60e+00, 9.50e+00, 1.00e+01, 4.60e+00, 1.57e+01, 8.70e+00,
# ...

# %%
data['Sugars'].nunique()
# Out:
# 168

# %% [markdown]
# **Q5: For a numerical column of your choice, calculate the mean, median, and
# standard deviation.**

# %%
data['Saturated Fats'].mean()
# Out:
# 1.8295498614958448

# %%
data['Saturated Fats'].median()
# Out:
# 0.1

# %%
data['Saturated Fats'].std()
# Out:
# 11.135123913777532

# %% [markdown]
# **Q6: Identify any potential outliers in a numerical column of your choice. Explain your approach.**

# %%
IQR = Q3 - Q1

Q1 = data['Water'].quantile(0.25)
Q3 = data['Water'].quantile(0.75)

lower_bound = Q1 - 1.5 * IQR
print(f"Lower Bound: {lower_bound}")
upper_bound = Q3 + 1.5 * IQR
print(f"\nUpper Bound: {upper_bound}")

outliers = data[(data['Water'] < lower_bound) | (data['Water'] > upper_bound)]
print("\nOutliers:\n")
print(outliers)
# Out:
# Lower Bound: -155.8125
#
# Upper Bound: 268.8875
#
# Outliers:
#
#      Unnamed: 0.1  Unnamed: 0                  food  Caloric Value   Fat  \
# 232           232         232     russet potato raw            292   0.3
# 374           374         374  azumaya tofu vitasoy            316  16.6
# 426           426         426          eggplant raw            115   0.8
# 446           446         446      acorn squash raw            172   0.4
# 469           469         469           sweet onion            106   0.3
# 627           627         627   oriental radish raw             61   0.3
# 652           652         652          rutabaga raw            286   1.2
# 664           664         664        carrots canned            104   0.6
# 666           666         666      asparagus canned             62   0.7
# 672           672         672   sweet potato canned            568   1.3
# 693           693         693  taco salad taco bell            906  48.9
#
# ...

# %% [markdown]
# **Q7: Find the correlation between numerical columns and discuss any interesting
# relationships.**

# %%
import seaborn as sns
import matplotlib.pyplot as plt
nutri_data=data[['Carbohydrates','Sugars','Protein','Dietary Fiber']]
corr = nutri_data.corr()

plt.figure(figsize=(5, 3))
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title('Heatmap of Correlation Matrix')
plt.show()

# %% [markdown]
# **Q8: Group the data by a categorical column and compute the aggregate statistics(e.g., mean, sum) for a numerical column.**

# %%
grouped_data = data.groupby('food')['Fat'].agg(['mean', 'sum'])
print("*******Aggregate Statistics*******\n")
print(grouped_data)
# Out:
# *******Aggregate Statistics*******
#
#                        mean     sum
# food
# acorn squash cooked   0.300   0.300
# acorn squash raw      0.400   0.400
# adobo fresco         60.200  60.200
# agar                  0.058   0.058
# almond butter         8.900   8.900
# ...                     ...     ...
# yellow tomato         0.600   0.600
# yuca cassava chips    0.400   0.400
# zucchini cooked       0.600   0.600
# zucchini raw          0.800   0.800
# zwieback              0.700   0.700
#
# [722 rows x 2 columns]

# %% [markdown]
# **Q9:Based on your analysis, provide a brief summary of any insights or patterns
# you discovered in the dataset.**

# %%
# This dataset covers a comprehensive range of nutritional metrics with 722 rows n 37 columns
# The dataset appears to be complete with no missing values across any of the 37 columns
# To count the number of missing values in each column 'isnull().sum()' is used
# The heatmap of the correlation matrix for the variables 'Carbohydrates', 'Sugars', 'Protein', and 'Dietary Fiber' provides a clear view of how these key nutritional components relate to each other.
# The color gradient in the heatmap visually represents the strength of correlations, with warmer colors (like red) typically indicating stronger positive correlations and cooler colors (like blue) indicating weaker or negative correlations.
