# %%
import pandas as pd
import numpy as np

# %% [markdown]
# read the data

# %%
df=pd.read_csv("/content/adult.csv")

# %% [markdown]
# Display the first 5 rows of the dataset.

# %%
print(df.head())
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18          ?  103497  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                  ?    Own-child  White  Female             0             0
#
#    hours-per-week native-country income
# 0              40  United-States  <=50K
# 1              50  United-States  <=50K
# 2              40  United-States   >50K
# 3              40  United-States   >50K
# 4              30  United-States  <=50K

# %% [markdown]
# summary of the DataFrame

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              48842 non-null  int64
#  1   workclass        48842 non-null  object
#  2   fnlwgt           48842 non-null  int64
#  3   education        48842 non-null  object
#  4   educational-num  48842 non-null  int64
#  5   marital-status   48842 non-null  object
#  6   occupation       48842 non-null  object
#  7   relationship     48842 non-null  object
#  8   race             48842 non-null  object
#  9   gender           48842 non-null  object
#  10  capital-gain     48842 non-null  int64
#  11  capital-loss     48842 non-null  int64
#  12  hours-per-week   48842 non-null  int64
#  13  native-country   48842 non-null  object
#  14  income           48842 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 5.6+ MB
# None

# %% [markdown]
# descriptive statistics for numeric columns

# %%
print(df.describe())
# Out:
#                 age        fnlwgt  educational-num  capital-gain  \
# count  48842.000000  4.884200e+04     48842.000000  48842.000000
# mean      38.643585  1.896641e+05        10.078089   1079.067626
# std       13.710510  1.056040e+05         2.570973   7452.019058
# min       17.000000  1.228500e+04         1.000000      0.000000
# 25%       28.000000  1.175505e+05         9.000000      0.000000
# 50%       37.000000  1.781445e+05        10.000000      0.000000
# 75%       48.000000  2.376420e+05        12.000000      0.000000
# max       90.000000  1.490400e+06        16.000000  99999.000000
#
#        capital-loss  hours-per-week
# count  48842.000000    48842.000000
# mean      87.502314       40.422382
# std      403.004552       12.391444
# min        0.000000        1.000000
# 25%        0.000000       40.000000
# 50%        0.000000       40.000000
# 75%        0.000000       45.000000
# max     4356.000000       99.000000

# %% [markdown]
# Display the column names of the DataFrame.

# %%
print(df.columns)
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %% [markdown]
# unique values in the 'workclass' column.

# %%
print(df['workclass'].unique())
# Out:
# ['Private' 'Local-gov' '?' 'Self-emp-not-inc' 'Federal-gov' 'State-gov'
#  'Self-emp-inc' 'Without-pay' 'Never-worked']

# %% [markdown]
# Create a new column 'income_binary' where <=50K is 0 and >50K is 1.

# %%
df['income_binary']=df['income'].apply(lambda x:0 if x=='<=50k' else 1)

# %% [markdown]
# Create a new column 'age_group' categorizing ages into 'Youth' (< 30), 'Adult' (30-60), and 'Senior' (60+).

# %%
df['age_group']=pd.cut(df['age'],bins=[0,29,59,100], labels=['Youth','Adult','Senior'])

# %% [markdown]
# Rename the 'educational-num' column to 'education_num'.

# %%
df.rename(columns={'educational-num':'education_num'},inplace=True)

# %% [markdown]
# Replace the missing values represented by '?' in 'workclass' and 'occupation' columns with 'Unknown'.

# %%
 df['workclass'].replace('?', 'Unknown', inplace=True)
 df['occupation'].replace('?', 'Unknown', inplace=True)

# %% [markdown]
# Calculate the average age for each workclass.

# %%
 avg_age_workclass = df.groupby('workclass')['age'].mean()
 print(avg_age_workclass)
# Out:
# workclass
# Federal-gov         42.577514
# Local-gov           41.676020
# Never-worked        19.900000
# Private             36.903144
# Self-emp-inc        45.799410
# Self-emp-not-inc    45.332470
# State-gov           39.512367
# Unknown             40.141122
# Without-pay         47.285714
# Name: age, dtype: float64

# %% [markdown]
# Find the total capital-gain for each gender.

# %%
total_capital_gain_gender = df.groupby('gender')['capital-gain'].sum()
print(total_capital_gain_gender)
# Out:
# gender
# Female     9403120
# Male      43300701
# Name: capital-gain, dtype: int64

# %% [markdown]
# Get the count of each marital-status category.

# %%
marital_status_counts = df['marital-status'].value_counts()
print(marital_status_counts)
# Out:
# marital-status
# Married-civ-spouse       22379
# Never-married            16117
# Divorced                  6633
# Separated                 1530
# Widowed                   1518
# Married-spouse-absent      628
# Married-AF-spouse           37
# Name: count, dtype: int64

# %% [markdown]
# Find the mean hours-per-week worked by individuals in different education levels.

# %%
mean_hours_by_education = df.groupby('education')['hours-per-week'].mean()
print(mean_hours_by_education)
# Out:
# education
# 10th            36.986321
# 11th            33.952539
# 12th            35.374429
# 1st-4th         38.761134
# 5th-6th         38.923379
# 7th-8th         39.003141
# 9th             38.359788
# Assoc-acdm      40.809494
# Assoc-voc       41.658418
# Bachelors       42.482492
# Doctorate       46.582492
# HS-grad         40.640775
# Masters         43.575837
# Preschool       36.566265
# Prof-school     47.579137
# Some-college    38.865784
# Name: hours-per-week, dtype: float64

# %% [markdown]
# Calculate the mean, median, and standard deviation of 'fnlwgt' for each race.

# %%
stats_fnlwgt_by_race = df.groupby('race')['fnlwgt'].agg(['mean', 'median', 'std'])
print(stats_fnlwgt_by_race)
# Out:
#                              mean    median            std
# race
# Amer-Indian-Eskimo  120110.985106  101579.0   94655.908850
# Asian-Pac-Islander  159796.946675  139850.0   86997.647681
# Black               230485.070438  208266.0  125445.929357
# Other               195715.689655  188066.5   94063.712981
# White               186894.995738  177287.0  102637.466726

# %% [markdown]
# Get the unique values and their counts for the 'native-country' column

# %%
native_country_counts = df['native-country'].value_counts()
print(native_country_counts)
# Out:
# native-country
# United-States                 43832
# Mexico                          951
# ?                               857
# Philippines                     295
# Germany                         206
# Puerto-Rico                     184
# Canada                          182
# El-Salvador                     155
# India                           151
# Cuba                            138
# England                         127
# China                           122
# South                           115
# Jamaica                         106
# Italy                           105
# Dominican-Republic              103
# Japan                            92
# Guatemala                        88
# Poland                           87
# Vietnam                          86
# Columbia                         85
# Haiti                            75
# Portugal                         67
# Taiwan                           65
# Iran                             59
# Greece                           49
# Nicaragua                        49
# Peru                             46
# Ecuador                          45
# France                           38
# Ireland                          37
# Hong                             30
# Thailand                         30
# Cambodia                         28
# Trinadad&Tobago                  27
# Laos                             23
# Yugoslavia                       23
# Outlying-US(Guam-USVI-etc)       23
# Scotland                         21
# Honduras                         20
# Hungary                          19
# Holand-Netherlands                1
# Name: count, dtype: int64

# %% [markdown]
# Filter the dataset to include only individuals with income >50K.

# %%
high_income_df = df[df['income'] == '>50K']
print(high_income_df.head())
# Out:
#     age         workclass  fnlwgt     education  education_num  \
# 2    28         Local-gov  336951    Assoc-acdm             12
# 3    44           Private  160323  Some-college             10
# 7    63  Self-emp-not-inc  104626   Prof-school             15
# 10   65           Private  184454       HS-grad              9
# 14   48           Private  279724       HS-grad              9
#
#         marital-status         occupation relationship   race gender  \
# 2   Married-civ-spouse    Protective-serv      Husband  White   Male
# 3   Married-civ-spouse  Machine-op-inspct      Husband  Black   Male
# 7   Married-civ-spouse     Prof-specialty      Husband  White   Male
# 10  Married-civ-spouse  Machine-op-inspct      Husband  White   Male
# 14  Married-civ-spouse  Machine-op-inspct      Husband  White   Male
#
#     capital-gain  capital-loss  hours-per-week native-country income  \
# 2              0             0              40  United-States   >50K
# 3           7688             0              40  United-States   >50K
# 7           3103             0              32  United-States   >50K
# 10          6418             0              40  United-States   >50K
# 14          3103             0              48  United-States   >50K
#
#     income binary age_group
# 2               1     Youth
# 3               1     Adult
# 7               1    Senior
# 10              1    Senior
# 14              1     Adult

# %% [markdown]
# Sort the dataset by age in descending order.

# %%
sorted_by_age_df = df.sort_values(by='age', ascending=False)
print(sorted_by_age_df.head())
# Out:
#        age  workclass  fnlwgt education  education_num      marital-status  \
# 40519   90    Unknown  166343   1st-4th              2             Widowed
# 21553   90    Private  141758       9th              5       Never-married
# 47977   90    Unknown  313986   HS-grad              9  Married-civ-spouse
# 21651   90  Local-gov  227796   Masters             14  Married-civ-spouse
# 41584   90    Unknown  175444   7th-8th              4           Separated
#
#             occupation   relationship   race  gender  capital-gain  \
# 40519          Unknown  Not-in-family  Black  Female             0
# 21553     Adm-clerical  Not-in-family  White  Female             0
# 47977          Unknown        Husband  White    Male             0
# 21651  Exec-managerial        Husband  White    Male         20051
# 41584          Unknown  Not-in-family  White  Female             0
#
#        capital-loss  hours-per-week native-country income  income binary  \
# 40519             0              40  United-States  <=50K              1
# 21553             0              40  United-States  <=50K              1
# 47977             0              40  United-States   >50K              1
# 21651             0              60  United-States   >50K              1
# 41584             0              15  United-States  <=50K              1
#
#       age_group
# 40519    Senior
# 21553    Senior
# 47977    Senior
# 21651    Senior
# 41584    Senior

# %% [markdown]
# Filter the dataset to include only individuals who work more than 40 hours per week.

# %%
over_40_hours_df = df[df['hours-per-week'] > 40]
print(over_40_hours_df.head())
# Out:
#     age workclass  fnlwgt  education  education_num      marital-status  \
# 1    38   Private   89814    HS-grad              9  Married-civ-spouse
# 14   48   Private  279724    HS-grad              9  Married-civ-spouse
# 15   43   Private  346189    Masters             14  Married-civ-spouse
# 19   40   Private   85019  Doctorate             16  Married-civ-spouse
# 20   34   Private  107914  Bachelors             13  Married-civ-spouse
#
#            occupation relationship                race gender  capital-gain  \
# 1     Farming-fishing      Husband               White   Male             0
# 14  Machine-op-inspct      Husband               White   Male          3103
# 15    Exec-managerial      Husband               White   Male             0
# 19     Prof-specialty      Husband  Asian-Pac-Islander   Male             0
# 20       Tech-support      Husband               White   Male             0
#
#     capital-loss  hours-per-week native-country income  income binary  \
# 1              0              50  United-States  <=50K              1
# 14             0              48  United-States   >50K              1
# 15             0              50  United-States   >50K              1
# 19             0              45              ?   >50K              1
# 20             0              47  United-States   >50K              1
#
#    age_group
# 1      Adult
# 14     Adult
# 15     Adult
# 19     Adult
# 20     Adult

# %%
Calculate the percentage of missing values in each column.

# %%
missing_values_percentage = df.isnull().mean() * 100
print(missing_values_percentage)
# Out:
# age               0.0
# workclass         0.0
# fnlwgt            0.0
# education         0.0
# education_num     0.0
# marital-status    0.0
# occupation        0.0
# relationship      0.0
# race              0.0
# gender            0.0
# capital-gain      0.0
# capital-loss      0.0
# hours-per-week    0.0
# native-country    0.0
# income            0.0
# income binary     0.0
# age_group         0.0
# dtype: float64

# %% [markdown]
# Calculate the median income by education level and gender.

# %%
median_income_by_edu_gender = df.groupby(['education', 'gender'])['income_binary'].median()
print(median_income_by_edu_gender)
# Out:
# education     gender
# 10th          Female    1.0
#               Male      1.0
# 11th          Female    1.0
#               Male      1.0
# 12th          Female    1.0
#               Male      1.0
# 1st-4th       Female    1.0
#               Male      1.0
# 5th-6th       Female    1.0
#               Male      1.0
# 7th-8th       Female    1.0
#               Male      1.0
# 9th           Female    1.0
#               Male      1.0
# Assoc-acdm    Female    1.0
#               Male      1.0
# Assoc-voc     Female    1.0
#               Male      1.0
# Bachelors     Female    1.0
#               Male      1.0
# Doctorate     Female    1.0
#               Male      1.0
# HS-grad       Female    1.0
#               Male      1.0
# Masters       Female    1.0
#               Male      1.0
# Preschool     Female    1.0
#               Male      1.0
# Prof-school   Female    1.0
#               Male      1.0
# Some-college  Female    1.0
#               Male      1.0
# Name: income_binary, dtype: float64

# %% [markdown]
# Find the top 3 occupations with the highest average capital-gain.

# %%
top_3_occupations = df.groupby('occupation')['capital-gain'].mean().nlargest(3)
print(top_3_occupations)
# Out:
# occupation
# Prof-specialty     2745.918017
# Exec-managerial    2277.755504
# Sales              1266.898256
# Name: capital-gain, dtype: float64

# %% [markdown]
# Filter the dataset to include individuals who are 'Married-civ-spouse' and have an income >50K.

# %%
married_high_income_df = df[(df['marital-status'] == 'Married-civ-spouse') & (df['income'] == '>50K')]
print(married_high_income_df.head())
# Out:
#     age         workclass  fnlwgt     education  education_num  \
# 2    28         Local-gov  336951    Assoc-acdm             12
# 3    44           Private  160323  Some-college             10
# 7    63  Self-emp-not-inc  104626   Prof-school             15
# 10   65           Private  184454       HS-grad              9
# 14   48           Private  279724       HS-grad              9
#
#         marital-status         occupation relationship   race gender  \
# 2   Married-civ-spouse    Protective-serv      Husband  White   Male
# 3   Married-civ-spouse  Machine-op-inspct      Husband  Black   Male
# 7   Married-civ-spouse     Prof-specialty      Husband  White   Male
# 10  Married-civ-spouse  Machine-op-inspct      Husband  White   Male
# 14  Married-civ-spouse  Machine-op-inspct      Husband  White   Male
#
#     capital-gain  capital-loss  hours-per-week native-country income  \
# 2              0             0              40  United-States   >50K
# 3           7688             0              40  United-States   >50K
# 7           3103             0              32  United-States   >50K
# 10          6418             0              40  United-States   >50K
# 14          3103             0              48  United-States   >50K
#
#     income binary age_group  income_binary
# 2               1     Youth              1
# 3               1     Adult              1
# 7               1    Senior              1
# 10              1    Senior              1
# 14              1     Adult              1
